# %% [markdown]
# # General chatbot

# %%
-------- General QA Bot API - Single-Line cURL Commands ----------

Standard QA Endpoint
Description: Send a question and get full response
curl -X POST "http://34.68.84.147:8080/api/qa_bot" -H "Content-Type: application/json" -d '{"question":"What is in this image?","session_id":"my_session_1","base64_images":["......"],"base64_files":[],"base64_audios":[]}'
curl -X POST "http://localhost:8080/api/qa_bot" -H "Content-Type: application/json" -d '{"question":"What is in this image?","session_id":"my_session_1","base64_images":["......"],"base64_files":[],"base64_audios":[]}'

Streaming QA Endpoint
Description: Send a question and receive response token-by-token
curl -N -X POST "http://34.68.84.147:8080/api/qa_bot_stream" -H "Content-Type: application/json" -H "Accept: text/event-stream" -d '{"question":"Analyze this PDF","session_id":"my_session_2","base64_images":[],"base64_files":["......"],"base64_audios":[]}'
curl -N -X POST "http://localhost:8080/api/qa_bot_stream" -H "Content-Type: application/json" -H "Accept: text/event-stream" -d '{"question":"Analyze this PDF","session_id":"my_session_2","base64_images":[],"base64_files":["......"],"base64_audios":[]}'

# %% [markdown]
# # Deep chatbot

# %%
-------- Deep Bot Chat API - Single-Line cURL Commands ----------

Standard QA Endpoint
Description: Ask a question with optional images, files, or audio and get full response
curl -X POST "http://34.68.84.147:8080/api/deep_qa_bot" -H "Content-Type: application/json" -d '{"question":"What is in this image?","session_id":"my_session_1","base64_images":[],"base64_files":[],"base64_audios":[]}'
curl -X POST "http://localhost:8080/api/deep_qa_bot" -H "Content-Type: application/json" -d '{"question":"What is in this image?","session_id":"my_session_1","base64_images":[],"base64_files":[],"base64_audios":[]}'

Standard QA Endpoint (with image example)
Description: Ask question with base64 image input
curl -X POST "http://34.68.84.147:8080/api/deep_qa_bot" -H "Content-Type: application/json" -d '{"question":"What is this image about?","session_id":"session_abc123","base64_images":["......"],"base64_files":[],"base64_audios":[]}'
curl -X POST "http://localhost:8080/api/deep_qa_bot" -H "Content-Type: application/json" -d '{"question":"What is this image about?","session_id":"session_abc123","base64_images":["......"],"base64_files":[],"base64_audios":[]}'

Standard QA Endpoint (with file example)
Description: Ask question with base64 file input
curl -X POST "http://34.68.84.147:8080/api/deep_qa_bot" -H "Content-Type: application/json" -d '{"question":"Analyze this document","session_id":"session_file_001","base64_images":[],"base64_files":["......"],"base64_audios":[]}'
curl -X POST "http://localhost:8080/api/deep_qa_bot" -H "Content-Type: application/json" -d '{"question":"Analyze this document","session_id":"session_file_001","base64_images":[],"base64_files":["......"],"base64_audios":[]}'

Streaming QA Endpoint
Description: Ask question and receive streaming response token-by-token
curl -N -X POST "http://34.68.84.147:8080/api/deep_qa_bot_stream" -H "Content-Type: application/json" -H "Accept: text/event-stream" -d '{"question":"Analyze this PDF","session_id":"my_session_2","base64_images":[],"base64_files":[],"base64_audios":[]}'
curl -N -X POST "http://localhost:8080/api/deep_qa_bot_stream" -H "Content-Type: application/json" -H "Accept: text/event-stream" -d '{"question":"Analyze this PDF","session_id":"my_session_2","base64_images":[],"base64_files":[],"base64_audios":[]}'

Streaming QA Endpoint (with file example)
Description: Streaming analysis with base64 file input
curl -N -X POST "http://34.68.84.147:8080/api/deep_qa_bot_stream" -H "Content-Type: application/json" -H "Accept: text/event-stream" -d '{"question":"Analyze this document for me","session_id":"session_xyz789","base64_images":[],"base64_files":["......"],"base64_audios":[]}'
curl -N -X POST "http://localhost:8080/api/deep_qa_bot_stream" -H "Content-Type: application/json" -H "Accept: text/event-stream" -d '{"question":"Analyze this document for me","session_id":"session_xyz789","base64_images":[],"base64_files":["......"],"base64_audios":[]}'

# %% [markdown]
# # Report generaion chatbot

# %%
-------- Report Generation Bot API - Single-Line cURL Commands ----------

Standard Report Generation - Company Performance
Description: Generates full company performance report
curl -X POST "http://34.68.84.147:8080/api/deep_qa_bot_report" -H "Content-Type: application/json" -d '{"session_id":"report_company_1","report_type":"company_performance_and_investment_thesis","ticker":"GOOGL","time_horizon":"last 5 years","instructions":"Include revenue, margins, and growth drivers"}'
curl -X POST "http://localhost:8080/api/deep_qa_bot_report" -H "Content-Type: application/json" -d '{"session_id":"report_company_1","report_type":"company_performance_and_investment_thesis","ticker":"GOOGL","time_horizon":"last 5 years","instructions":"Include revenue, margins, and growth drivers"}'

Standard Report Generation - Industry Deep Drive
Description: Generates full industry report
curl -X POST "http://34.68.84.147:8080/api/deep_qa_bot_report" -H "Content-Type: application/json" -d '{"session_id":"report_industry_1","report_type":"industry_deep_drive","industry_name":"Artificial Intelligence","time_horizon":"last 3 years","instructions":"Highlight key players and trends"}'
curl -X POST "http://localhost:8080/api/deep_qa_bot_report" -H "Content-Type: application/json" -d '{"session_id":"report_industry_1","report_type":"industry_deep_drive","industry_name":"Artificial Intelligence","time_horizon":"last 3 years","instructions":"Highlight key players and trends"}'

Streaming Report Generation - Company Performance
Description: Streams company report in real time
curl -N -X POST "http://34.68.84.147:8080/api/deep_qa_bot_stream_report" -H "Content-Type: application/json" -H "Accept: text/event-stream" -d '{"session_id":"stream_report_company_1","report_type":"company_performance_and_investment_thesis","ticker":"GOOGL","time_horizon":"last 5 years","instructions":"Include financial analysis and investment thesis"}'
curl -N -X POST "http://localhost:8080/api/deep_qa_bot_stream_report" -H "Content-Type: application/json" -H "Accept: text/event-stream" -d '{"session_id":"stream_report_company_1","report_type":"company_performance_and_investment_thesis","ticker":"GOOGL","time_horizon":"last 5 years","instructions":"Include financial analysis and investment thesis"}'

Streaming Report Generation - Industry Deep Drive
Description: Streams industry report in real time
curl -N -X POST "http://34.68.84.147:8080/api/deep_qa_bot_stream_report" -H "Content-Type: application/json" -H "Accept: text/event-stream" -d '{"session_id":"stream_report_industry_1","report_type":"industry_deep_drive","industry_name":"Renewable Energy","time_horizon":"last 5 years","instructions":"Include solar, wind, and battery storage"}'
curl -N -X POST "http://localhost:8080/api/deep_qa_bot_stream_report" -H "Content-Type: application/json" -H "Accept: text/event-stream" -d '{"session_id":"stream_report_industry_1","report_type":"industry_deep_drive","industry_name":"Renewable Energy","time_horizon":"last 5 years","instructions":"Include solar, wind, and battery storage"}'

# %% [markdown]
# # Specil metric calculatiosn apis

# %%
-------- Special Metrics API - Single-Line cURL Commands ----------

Get Market Cap
Description: Fetch market capitalization of a stock ticker
curl -X POST "http://34.68.84.147:8080/api/special_metrics/market_cap" -H "Content-Type: application/json" -d '{"ticker":"AAPL"}'
curl -X POST "http://localhost:8080/api/special_metrics/market_cap" -H "Content-Type: application/json" -d '{"ticker":"AAPL"}'

Get Shares Outstanding
Description: Fetch total number of shares outstanding
curl -X POST "http://34.68.84.147:8080/api/special_metrics/shares_outstanding" -H "Content-Type: application/json" -d '{"ticker":"MSFT"}'
curl -X POST "http://localhost:8080/api/special_metrics/shares_outstanding" -H "Content-Type: application/json" -d '{"ticker":"MSFT"}'

Get Stock Price
Description: Fetch current stock price
curl -X POST "http://34.68.84.147:8080/api/special_metrics/stock_price" -H "Content-Type: application/json" -d '{"ticker":"GOOGL"}'
curl -X POST "http://localhost:8080/api/special_metrics/stock_price" -H "Content-Type: application/json" -d '{"ticker":"GOOGL"}'

Get Intrinsic to Market Cap Ratio
Description: Fetch intrinsic value to market cap ratio
curl -X POST "http://34.68.84.147:8080/api/special_metrics/intrinsic_to_mc" -H "Content-Type: application/json" -d '{"ticker":"TSLA"}'
curl -X POST "http://localhost:8080/api/special_metrics/intrinsic_to_mc" -H "Content-Type: application/json" -d '{"ticker":"TSLA"}'

Get Intrinsic Value
Description: Fetch intrinsic (equity) value
curl -X POST "http://34.68.84.147:8080/api/special_metrics/intrinsic_value" -H "Content-Type: application/json" -d '{"ticker":"AAPL"}'
curl -X POST "http://localhost:8080/api/special_metrics/intrinsic_value" -H "Content-Type: application/json" -d '{"ticker":"AAPL"}'

Get 5-Year Average ROIC
Description: Fetch 5-year average ROIC
curl -X POST "http://34.68.84.147:8080/api/special_metrics/roic" -H "Content-Type: application/json" -d '{"ticker":"MSFT"}'
curl -X POST "http://localhost:8080/api/special_metrics/roic" -H "Content-Type: application/json" -d '{"ticker":"MSFT"}'

Get Earnings Yield
Description: Calculate earnings yield
curl -X POST "http://34.68.84.147:8080/api/special_metrics/earnings_yield" -H "Content-Type: application/json" -d '{"ticker":"GOOGL"}'
curl -X POST "http://localhost:8080/api/special_metrics/earnings_yield" -H "Content-Type: application/json" -d '{"ticker":"GOOGL"}'

Get Margin of Safety
Description: Calculate margin of safety
curl -X POST "http://34.68.84.147:8080/api/special_metrics/margin_of_safety" -H "Content-Type: application/json" -d '{"ticker":"GOOGL"}'
curl -X POST "http://localhost:8080/api/special_metrics/margin_of_safety" -H "Content-Type: application/json" -d '{"ticker":"GOOGL"}'

Get Multiples Table Metric
Description: Fetch specific financial metric
curl -X POST "http://34.68.84.147:8080/api/special_metrics/multiples_table_metric" -H "Content-Type: application/json" -d '{"ticker":"GOOGL","metric_name":"MarketCap_Fundamental"}'
curl -X POST "http://localhost:8080/api/special_metrics/multiples_table_metric" -H "Content-Type: application/json" -d '{"ticker":"GOOGL","metric_name":"MarketCap_Fundamental"}'

Get Investment Factor Ranking (Specific Tickers)
Description: Rank selected tickers by investment factors
curl -X POST "http://34.68.84.147:8080/api/special_metrics/investment_factor_ranking_table" -H "Content-Type: application/json" -d '{"tickers":["AAPL","MSFT","GOOGL","TSLA","AMZN"]}'
curl -X POST "http://localhost:8080/api/special_metrics/investment_factor_ranking_table" -H "Content-Type: application/json" -d '{"tickers":["AAPL","MSFT","GOOGL","TSLA","AMZN"]}'

Get Investment Factor Ranking (All Companies)
Description: Fetch ranking for all companies
curl -X GET "http://34.68.84.147:8080/api/special_metrics/investment_factor_ranking_table_for_all_companies"
curl -X GET "http://localhost:8080/api/special_metrics/investment_factor_ranking_table_for_all_companies"

Get Investment Factor Ranking (Specific Date)
Description: Fetch ranking for all companies on a specific date
curl -X GET "http://34.68.84.147:8080/api/special_metrics/investment_factor_ranking_table_for_all_companies/2025-12-10"
curl -X GET "http://localhost:8080/api/special_metrics/investment_factor_ranking_table_for_all_companies/2025-12-10"

# %% [markdown]
# # Neo4j Graph Database Access Endpoints

# %%
-------- Neo4j Graph Database API - Single-Line cURL Commands ----------

Execute Cypher Query (Simple Read)
Description: Execute a basic Cypher query to fetch sectors
curl -X POST "http://34.68.84.147:8080/api/graphdb/cypher" -H "Content-Type: application/json" -d '{"query":"MATCH (s:Sector) RETURN s LIMIT 5"}'
curl -X POST "http://localhost:8080/api/graphdb/cypher" -H "Content-Type: application/json" -d '{"query":"MATCH (s:Sector) RETURN s LIMIT 5"}'

Execute Cypher Query (With Parameters)
Description: Execute Cypher query with parameters
curl -X POST "http://34.68.84.147:8080/api/graphdb/cypher" -H "Content-Type: application/json" -d '{"query":"MATCH (s:Sector {sectorId: $sectorId}) RETURN s","parameters":{"sectorId":"TECH"}}'
curl -X POST "http://localhost:8080/api/graphdb/cypher" -H "Content-Type: application/json" -d '{"query":"MATCH (s:Sector {sectorId: $sectorId}) RETURN s","parameters":{"sectorId":"TECH"}}'

Execute Cypher Query (Complex Relationship Query)
Description: Fetch sectors, industries, and companies together
curl -X POST "http://34.68.84.147:8080/api/graphdb/cypher" -H "Content-Type: application/json" -d '{"query":"MATCH (s:Sector)<-[:BELONG_TO]-(i:Industry)<-[:BELONG_TO]-(c:Company) WHERE s.sectorId = $sectorId RETURN s.sectorName, i.industryName, c.companyName","parameters":{"sectorId":"TECH"}}'
curl -X POST "http://localhost:8080/api/graphdb/cypher" -H "Content-Type: application/json" -d '{"query":"MATCH (s:Sector)<-[:BELONG_TO]-(i:Industry)<-[:BELONG_TO]-(c:Company) WHERE s.sectorId = $sectorId RETURN s.sectorName, i.industryName, c.companyName","parameters":{"sectorId":"TECH"}}'

Execute Cypher Query (Write Query - Create Sector)
Description: Create new sector in Neo4j database
curl -X POST "http://34.68.84.147:8080/api/graphdb/cypher" -H "Content-Type: application/json" -d '{"query":"CREATE (s:Sector {sectorId: $id, sectorName: $name}) RETURN s","parameters":{"id":"AI_SECTOR","name":"Artificial Intelligence"},"mode":"write"}'
curl -X POST "http://localhost:8080/api/graphdb/cypher" -H "Content-Type: application/json" -d '{"query":"CREATE (s:Sector {sectorId: $id, sectorName: $name}) RETURN s","parameters":{"id":"AI_SECTOR","name":"Artificial Intelligence"},"mode":"write"}'

List All Sectors
Description: Retrieve all sectors from graph database
curl -X GET "http://34.68.84.147:8080/api/graphdb/sectors"
curl -X GET "http://localhost:8080/api/graphdb/sectors"

List Industries by Sector ID
Description: Retrieve industries using sectorId
curl -X GET "http://34.68.84.147:8080/api/graphdb/industries_when_sector_given?sectorId=TECH"
curl -X GET "http://localhost:8080/api/graphdb/industries_when_sector_given?sectorId=TECH"

List Industries by Sector Name
Description: Retrieve industries using sectorName
curl -X GET "http://34.68.84.147:8080/api/graphdb/industries_when_sector_given?sectorName=Technology"
curl -X GET "http://localhost:8080/api/graphdb/industries_when_sector_given?sectorName=Technology"

List Companies by Industry ID
Description: Retrieve companies using industryId
curl -X GET "http://34.68.84.147:8080/api/graphdb/companies_when_industry_given?industryId=SOFTWARE"
curl -X GET "http://localhost:8080/api/graphdb/companies_when_industry_given?industryId=SOFTWARE"

List Companies by Industry Name
Description: Retrieve companies using industryName
curl -X GET "http://34.68.84.147:8080/api/graphdb/companies_when_industry_given?industryName=Software Development"
curl -X GET "http://localhost:8080/api/graphdb/companies_when_industry_given?industryName=Software Development"

List Companies by Sector ID
Description: Retrieve companies using sectorId
curl -X GET "http://34.68.84.147:8080/api/graphdb/companies_when_sector_given?sectorId=TECH"
curl -X GET "http://localhost:8080/api/graphdb/companies_when_sector_given?sectorId=TECH"

List Companies by Sector Name
Description: Retrieve companies using sectorName
curl -X GET "http://34.68.84.147:8080/api/graphdb/companies_when_sector_given?sectorName=Technology"
curl -X GET "http://localhost:8080/api/graphdb/companies_when_sector_given?sectorName=Technology"

List All Companies
Description: Retrieve all companies from graph database
curl -X GET "http://34.68.84.147:8080/api/graphdb/companies"
curl -X GET "http://localhost:8080/api/graphdb/companies"

# %% [markdown]
# # Neo4j Update Graph Enpoints

# %%
-------- Neo4j Update Graph API - Single-Line cURL Commands ----------

Execute Graph Update (Create Node)
Description: Create a new company node using natural language
curl -X POST "http://34.68.84.147:8080/api/update_graph/execute" -H "Content-Type: application/json" -d '{"question":"Create a new company node for Amazon with ticker AMZN in the Retail industry","session_id":"update_session_abc123"}'
curl -X POST "http://localhost:8080/api/update_graph/execute" -H "Content-Type: application/json" -d '{"question":"Create a new company node for Amazon with ticker AMZN in the Retail industry","session_id":"update_session_abc123"}'

Execute Graph Update (Modify Property)
Description: Update existing company property using natural language condition
curl -X POST "http://34.68.84.147:8080/api/update_graph/execute" -H "Content-Type: application/json" -d '{"question":"if AMZN company node Contain CIKCODE as 123 , then please change it to 567","session_id":"update_session_abc123"}'
curl -X POST "http://localhost:8080/api/update_graph/execute" -H "Content-Type: application/json" -d '{"question":"if AMZN company node Contain CIKCODE as 123 , then please change it to 567","session_id":"update_session_abc123"}'

Execute Graph Update (Validate and Update)
Description: Validate existing value and update if condition is met
curl -X POST "http://34.68.84.147:8080/api/update_graph/execute" -H "Content-Type: application/json" -d '{"question":"check if WLMTS Revenue is 12k , if it is yes , change it into 14k","session_id":"update_session_abc123"}'
curl -X POST "http://localhost:8080/api/update_graph/execute" -H "Content-Type: application/json" -d '{"question":"check if WLMTS Revenue is 12k , if it is yes , change it into 14k","session_id":"update_session_abc123"}'

Execute Graph Update (Auto Session)
Description: Execute graph update without providing session_id
curl -X POST "http://34.68.84.147:8080/api/update_graph/execute" -H "Content-Type: application/json" -d '{"question":"Create a new company node for Microsoft with ticker MSFT in the Technology industry"}'
curl -X POST "http://localhost:8080/api/update_graph/execute" -H "Content-Type: application/json" -d '{"question":"Create a new company node for Microsoft with ticker MSFT in the Technology industry"}'

# %% [markdown]
# # Financial Analysis API Contract

# %%
-------- Financial Analysis API - Single-Line cURL Commands ----------

Get All Companies
Description: Retrieve all available companies for analysis
curl -X GET "http://34.68.84.147:8080/api/central/companies" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/companies" -H "Content-Type: application/json"

Get Available Metrics
Description: Retrieve available financial metrics
curl -X GET "http://34.68.84.147:8080/api/central/metrics?include_predicted=false&display_names=false" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/metrics?include_predicted=false&display_names=false" -H "Content-Type: application/json"

Get Industries
Description: Retrieve all industries and associated companies
curl -X GET "http://34.68.84.147:8080/api/central/industries" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/industries" -H "Content-Type: application/json"

Get Aggregated Company Data
Description: Retrieve historical performance data for companies
curl -X GET "http://34.68.84.147:8080/api/central/aggregated-data?tickers=AAPL,MSFT&metric=Revenue&period=5Y&periodType=Annual" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/aggregated-data?tickers=AAPL,MSFT&metric=Revenue&period=5Y&periodType=Annual" -H "Content-Type: application/json"

Get Industry Comparison
Description: Compare performance across industries
curl -X GET "http://34.68.84.147:8080/api/central/industry-comparison?industries=Software%20-%20Infrastructure,Financial%20Services&metric=Revenue&period=5Y" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/industry-comparison?industries=Software%20-%20Infrastructure,Financial%20Services&metric=Revenue&period=5Y" -H "Content-Type: application/json"

Get Income Statement
Description: Retrieve income statement for a company
curl -X GET "http://34.68.84.147:8080/api/central/financials/income-statement/AAPL" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/financials/income-statement/AAPL" -H "Content-Type: application/json"

Get Balance Sheet
Description: Retrieve balance sheet for a company
curl -X GET "http://34.68.84.147:8080/api/central/financials/balance-sheet/AAPL" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/financials/balance-sheet/AAPL" -H "Content-Type: application/json"

Get Cash Flow Statement
Description: Retrieve cash flow statement for a company
curl -X GET "http://34.68.84.147:8080/api/central/financials/cash-flow/AAPL" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/financials/cash-flow/AAPL" -H "Content-Type: application/json"

Get NOPAT Analysis
Description: Retrieve Net Operating Profit After Tax analysis
curl -X GET "http://34.68.84.147:8080/api/central/analysis/nopat/AAPL" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/analysis/nopat/AAPL" -H "Content-Type: application/json"

Get Invested Capital Analysis
Description: Retrieve invested capital breakdown
curl -X GET "http://34.68.84.147:8080/api/central/analysis/invested-capital/AAPL" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/analysis/invested-capital/AAPL" -H "Content-Type: application/json"

Get Free Cash Flow Analysis
Description: Retrieve free cash flow analysis
curl -X GET "http://34.68.84.147:8080/api/central/analysis/free-cash-flow/AAPL" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/analysis/free-cash-flow/AAPL" -H "Content-Type: application/json"

Get ROIC Analysis
Description: Retrieve Return on Invested Capital breakdown
curl -X GET "http://34.68.84.147:8080/api/central/analysis/roic/AAPL" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/analysis/roic/AAPL" -H "Content-Type: application/json"

Get Operational Performance
Description: Retrieve operational performance metrics
curl -X GET "http://34.68.84.147:8080/api/central/analysis/operational-performance/AAPL" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/analysis/operational-performance/AAPL" -H "Content-Type: application/json"

Get Financing Health
Description: Retrieve financing health metrics
curl -X GET "http://34.68.84.147:8080/api/central/analysis/financing-health/AAPL" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/analysis/financing-health/AAPL" -H "Content-Type: application/json"

Get Ranking Types
Description: Retrieve available ranking types
curl -X GET "http://34.68.84.147:8080/api/central/rankings/types" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/rankings/types" -H "Content-Type: application/json"

Get Historical Rankings
Description: Retrieve historical ranking data for companies
curl -X GET "http://34.68.84.147:8080/api/central/rankings/historical?tickers=WMT,COST&rankingType=overall&period=5Y" -H "Content-Type: application/json"
curl -X GET "http://localhost:8080/api/central/rankings/historical?tickers=WMT,COST&rankingType=overall&period=5Y" -H "Content-Type: application/json"

# %% [markdown]
# # Dynamic Table API – Common Contract

# %%
-------- Dynamic Table API - Single-Line cURL Commands ----------

Get 3 Statement Model Table
Description: Retrieve 3-statement financial model table for a ticker
curl -X POST "http://34.68.84.147:8080/api/dynamic_table/3StatementModel" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"
curl -X POST "http://localhost:8080/api/dynamic_table/3StatementModel" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"

Get Free Cash Flows Table
Description: Retrieve free cash flow table for a ticker
curl -X POST "http://34.68.84.147:8080/api/dynamic_table/FreeCashFlows" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"
curl -X POST "http://localhost:8080/api/dynamic_table/FreeCashFlows" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"

Get Reported Financials Table
Description: Retrieve reported financials table for a ticker
curl -X POST "http://34.68.84.147:8080/api/dynamic_table/ReportedFinancials" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"
curl -X POST "http://localhost:8080/api/dynamic_table/ReportedFinancials" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"

Get Invested Capital Table
Description: Retrieve invested capital table for a ticker
curl -X POST "http://34.68.84.147:8080/api/dynamic_table/InvestedCapital" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"
curl -X POST "http://localhost:8080/api/dynamic_table/InvestedCapital" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"

Get Performance Table
Description: Retrieve performance metrics table for a ticker
curl -X POST "http://34.68.84.147:8080/api/dynamic_table/Performance" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"
curl -X POST "http://localhost:8080/api/dynamic_table/Performance" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"

Get Historical CAGR Average Table
Description: Retrieve historical CAGR average table for a ticker
curl -X POST "http://34.68.84.147:8080/api/dynamic_table/HistoricalCagrAvg" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"
curl -X POST "http://localhost:8080/api/dynamic_table/HistoricalCagrAvg" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"

Get Extracted Items Table
Description: Retrieve extracted financial items table for a ticker
curl -X POST "http://34.68.84.147:8080/api/dynamic_table/ExtractedItems" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"
curl -X POST "http://localhost:8080/api/dynamic_table/ExtractedItems" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"

Get Valuation Forecast Driver Values Table
Description: Retrieve valuation forecast driver values table for a ticker
curl -X POST "http://34.68.84.147:8080/api/dynamic_table/ValuationForecastDriverValues" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"
curl -X POST "http://localhost:8080/api/dynamic_table/ValuationForecastDriverValues" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"

Get Valuation Summary Table
Description: Retrieve valuation summary table for a ticker
curl -X POST "http://34.68.84.147:8080/api/dynamic_table/ValuationSummary" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"
curl -X POST "http://localhost:8080/api/dynamic_table/ValuationSummary" -H "Content-Type: application/x-www-form-urlencoded" -d "ticker=AAPL"

# %% [markdown]
# # KPI Properties API

# %%
-------- KPI Properties API - Single-Line cURL Commands ----------

Get KPI Properties (Single Metric)
Description: Retrieve KPI metadata and properties for a specific metric
curl -X POST "http://34.68.84.147:8080/api/kpi/properties" -H "Content-Type: application/json" -d '{"metric_names":["Revenue"]}'
curl -X POST "http://localhost:8080/api/kpi/properties" -H "Content-Type: application/json" -d '{"metric_names":["Revenue"]}'

Get KPI Properties (Multiple Metrics)
Description: Retrieve KPI metadata and properties for multiple metrics
curl -X POST "http://34.68.84.147:8080/api/kpi/properties" -H "Content-Type: application/json" -d '{"metric_names":["Revenue","GrossMargin","EBITDA"]}'
curl -X POST "http://localhost:8080/api/kpi/properties" -H "Content-Type: application/json" -d '{"metric_names":["Revenue","GrossMargin","EBITDA"]}'
